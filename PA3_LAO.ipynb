# %%
import pandas as pd #Imports the Pandas Library

# %% [markdown]
# Problem 1

# %%
cars = pd.read_csv('cars.csv') #Prints the imported file cars.csv
cars
# Out:
#                   Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars.shape # The dataframs shape
# Out:
# (32, 12)

# %%
cars.columns #prints the columns
# Out:
# Index(['Model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='str')

# %%
cars_6_to_10 = cars.iloc[6:11] #printing row 6 to 10 including all of the columns
cars_6_to_10
# Out:
#          Model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 6   Duster 360  14.3    8  360.0  245  3.21  3.57  15.84   0   0     3     4
# 7    Merc 240D  24.4    4  146.7   62  3.69  3.19  20.00   1   0     4     2
# 8     Merc 230  22.8    4  140.8   95  3.92  3.15  22.90   1   0     4     2
# 9     Merc 280  19.2    6  167.6  123  3.92  3.44  18.30   1   0     4     4
# 10   Merc 280C  17.8    6  167.6  123  3.92  3.44  18.90   1   0     4     4

# %%
cars_6_to_10 = cars.loc[6:10, ['Model', 'mpg', 'cyl', 'hp', 'gear']] #prints row 6 to 10 with its corresponding column
cars_6_to_10
# Out:
#          Model   mpg  cyl   hp  gear
# 6   Duster 360  14.3    8  245     3
# 7    Merc 240D  24.4    4   62     4
# 8     Merc 230  22.8    4   95     4
# 9     Merc 280  19.2    6  123     4
# 10   Merc 280C  17.8    6  123     4

# %% [markdown]
# Problem 2

# %%
toyota = cars[cars["Model"] == "Toyota Corolla"] # printing the row of the Model that equates to Toyota Corolla
toyota
# Out:
#              Model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %%
pontiac = cars.loc[cars["Model"] == "Pontiac Firebird"] [["Model", "mpg", "hp", "wt"]] #Prints the row of Pontiac Firebird with the instructed columns
pontiac
# Out:
#                Model   mpg   hp     wt
# 24  Pontiac Firebird  19.2  175  3.845

# %% [markdown]
# Problem 3

# %%
selected_cars = pd.concat([
    cars[cars["Model"] == "Datsun 710"],
    cars[cars["Model"] == "Lotus Europa"],
    cars[cars["Model"] == "Ferrari Dino"]
])
selected_cars = selected_cars [["Model", "mpg", "cyl", "hp", "gear"]]
selected_cars #prints the rows of Datsun 710, Lotus Europa, and Ferrari Dino with its instructed columns
# Out:
#            Model   mpg  cyl   hp  gear
# 2     Datsun 710  22.8    4   93     4
# 27  Lotus Europa  30.4    4  113     5
# 29  Ferrari Dino  19.7    6  175     5

# %%
selected_cars.shape #prints the shape of the dataframe selected_cars
# Out:
# (3, 5)
